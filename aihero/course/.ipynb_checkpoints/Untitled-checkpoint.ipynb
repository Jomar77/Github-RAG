# %%
# %run main.py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\Documents\GitHub\Github-RAG\aihero\course\main.py:5
#       3 import requests
#       4 import frontmatter
# ----> 5 from aihero.course.chunking.paragraph_chunking import intelligent_chunk_documents
#       6 def read_repo_data(repo_owner, repo_name):
#       7     """
#       8     Download and parse all markdown files from a GitHub repository.
#       9
#    (...)     15         List of dictionaries containing file content and metadata
#      16     """
#
# ModuleNotFoundError: No module named 'aihero'
